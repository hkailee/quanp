# %%
# %matplotlib inline

import zipline
from zipline.api import order_target_percent, symbol,  \
    set_commission, set_slippage, schedule_function, \
    date_rules, time_rules
from datetime import datetime
import pytz
import matplotlib.pyplot as plt
import pyfolio as pf
import pandas as pd
import numpy as np  
from scipy import stats  
from zipline.finance.commission import PerDollar
from zipline.finance.slippage import VolumeShareSlippage, FixedSlippage

"""
Model Settings
"""
intial_portfolio = 10000000
momentum_window = 125
minimum_momentum = 40
portfolio_size = 30
vola_window = 20

"""
Commission and Slippage Settings
"""
enable_commission = True
commission_pct = 0.001
enable_slippage = True 
slippage_volume_limit = 0.25
slippage_impact = 0.1

"""
Helper functions.
"""

def momentum_score(ts):
    """
    Input:  Price time series.
    Output: Annualized exponential regression slope, 
            multiplied by the R2
    """
    # Make a list of consecutive numbers
    x = np.arange(len(ts)) 
    # Get logs
    log_ts = np.log(ts) 
    # Calculate regression values
    slope, intercept, r_value, p_value, std_err = stats.linregress(x, log_ts)
    # Annualize percent
    annualized_slope = (np.power(np.exp(slope), 252) - 1) * 100
    #Adjust for fitness
    score = annualized_slope * (r_value ** 2)
    return score

def volatility(ts):
    return ts.pct_change().rolling(vola_window).std().iloc[-1]

def output_progress(context):
    """
    Output some performance numbers during backtest run
    This code just prints out the past month's performance
    so that we have something to look at while the backtest runs.
    """
    
    # Get today's date
    today = zipline.api.get_datetime().date()
    
    # Calculate percent difference since last month
    perf_pct = (context.portfolio.portfolio_value / context.last_month) - 1
    
    # Print performance, format as percent with two decimals.
    print("{} - Last Month Result: {:.2%}".format(today, perf_pct))
    
    # Remember today's portfolio value for next month's calculation
    context.last_month = context.portfolio.portfolio_value

"""
Initialization and trading logic
"""
def initialize(context):
   
    # Set commission and slippage.
    if enable_commission:
        comm_model = PerDollar(cost=commission_pct)
    else:
        comm_model = PerDollar(cost=0.0)
    set_commission(comm_model)
    
    if enable_slippage:
        slippage_model=VolumeShareSlippage(volume_limit=slippage_volume_limit, price_impact=slippage_impact)
    else:
        slippage_model=FixedSlippage(spread=0.0)   
    set_slippage(slippage_model)    
    
    # Used only for progress output.
    context.last_month = intial_portfolio
    
    # Fetch and store index membership
    context.index_members = pd.read_csv('Data/index_members/sp500_20200801_v2.csv', index_col=0, parse_dates=[0])
    
    #Schedule rebalance monthly.
    schedule_function(
        func=rebalance,
        date_rule=date_rules.month_start(),
        time_rule=time_rules.market_open()
    )
    
def rebalance(context, data):
    # Write some progress output during the backtest
    output_progress(context)
    
    # Ok, let's find which stocks can be traded today.

    # First, get today's date
    today = zipline.api.get_datetime()
    
    # Second, get the index makeup for all days prior to today.
    all_prior = context.index_members.loc[context.index_members.index < today]
    
    # Now let's snag the first column of the last, i.e. latest, entry.
    latest_day = all_prior.iloc[-1,0]
    
    # Split the text string with tickers into a list
    list_of_tickers = latest_day.split(',')
    
    # Finally, get the Zipline symbols for the tickers
    todays_universe = [symbol(ticker) for ticker in list_of_tickers]
    
    # There's your daily universe. But we could of course have done this in one go.
    """       
    
    # This line below does the same thing,
    # using the same logic to fetch today's stocks.
    
    todays_universe = [
        symbol(ticker) for ticker in 
        context.index_members.loc[context.index_members.index < today].iloc[-1,0].split(',')
    ]
    """    
    
    # Get historical data
    hist = data.history(todays_universe, "close", momentum_window, "1d")

    # Make momentum ranking table
    ranking_table = hist.apply(momentum_score).sort_values(ascending=False)  
    
    """
    Sell Logic
    
    First we check if any existing position should be sold.
    * Sell if stock is no longer part of index.
    * Sell if stock has too low momentum value.
    """
    kept_positions = list(context.portfolio.positions.keys())
    for security in context.portfolio.positions:
        if (security not in todays_universe):
            order_target_percent(security, 0.0)
            kept_positions.remove(security)          
        elif ranking_table[security] < minimum_momentum:
            order_target_percent(security, 0.0)
            kept_positions.remove(security)         
      
    
    """
    Stock Selection Logic
    
    Check how many stocks we are keeping from last month.
    Fill from top of ranking list, until we reach the
    desired total number of portfolio holdings.
    """
    replacement_stocks = portfolio_size - len(kept_positions)
    buy_list = ranking_table.loc[
        ~ranking_table.index.isin(kept_positions)][:replacement_stocks]
    
    new_portfolio = pd.concat(
        (buy_list, 
         ranking_table.loc[ranking_table.index.isin(kept_positions)])
    )
    
    """
    Calculate inverse volatility for stocks, 
    and make target position weights.
    """
    vola_table = hist[new_portfolio.index].apply(volatility)
    inv_vola_table = 1 / vola_table 
    sum_inv_vola = np.sum(inv_vola_table)         
    vola_target_weights = inv_vola_table / sum_inv_vola
    
    for security, rank in new_portfolio.iteritems():
        weight = vola_target_weights[security]
        if security in kept_positions:
            order_target_percent(security, weight)
        else:
            if ranking_table[security] > minimum_momentum:
                order_target_percent(security, weight)

def analyze(context, perf):
    
    perf['max'] = perf.portfolio_value.cummax()
    perf['dd'] = (perf.portfolio_value / perf['max']) - 1
    maxdd = perf['dd'].min()
    
    ann_ret = (np.power((perf.portfolio_value.iloc[-1] / perf.portfolio_value.iloc[0]),(252 / len(perf)))) - 1
    
    print("Annualized Return: {:.2%} Max Drawdown: {:.2%}".format(ann_ret, maxdd))

    return   
        
# Set start and end date
start_date = pd.Timestamp('2001-2-5', tz='utc')
end_date = pd.Timestamp('2020-7-31', tz='utc')

perf = zipline.run_algorithm(
    start=start_date, end=end_date, 
    initialize=initialize, 
    analyze=analyze, 
    capital_base=intial_portfolio,  
    data_frequency = 'daily', 
    bundle='daily-csvdir-bundle')
# Out:
# /Users/leehongkai/anaconda/envs/trading/lib/python3.5/site-packages/empyrical/stats.py:704: RuntimeWarning: invalid value encountered in true_divide
#   out=out,
# /Users/leehongkai/anaconda/envs/trading/lib/python3.5/site-packages/empyrical/stats.py:790: RuntimeWarning: invalid value encountered in true_divide
#   np.divide(average_annual_return, annualized_downside_risk, out=out)
# 2001-03-01 - Last Month Result: 0.00%
# 2001-04-02 - Last Month Result: -5.29%
# 2001-05-01 - Last Month Result: 5.29%
# 2001-06-01 - Last Month Result: 1.84%
# 2001-07-02 - Last Month Result: -1.29%
# 2001-08-01 - Last Month Result: 2.26%
# 2001-09-04 - Last Month Result: -0.34%
# 2001-10-01 - Last Month Result: -5.98%
# 2001-11-01 - Last Month Result: 0.48%
# 2001-12-03 - Last Month Result: 2.48%
# 2002-01-02 - Last Month Result: -0.03%
# 2002-02-01 - Last Month Result: 0.68%
# 2002-03-01 - Last Month Result: 6.32%
# 2002-04-01 - Last Month Result: 0.46%
# 2002-05-01 - Last Month Result: -1.29%
# 2002-06-03 - Last Month Result: -3.98%
# 2002-07-01 - Last Month Result: -2.91%
# 2002-08-01 - Last Month Result: -11.24%
# 2002-09-03 - Last Month Result: -1.96%
# 2002-10-01 - Last Month Result: 0.22%
# 2002-11-01 - Last Month Result: 0.00%
# 2002-12-02 - Last Month Result: 0.26%
# 2003-01-02 - Last Month Result: 0.55%
# 2003-02-03 - Last Month Result: -3.15%
# 2003-03-03 - Last Month Result: 0.08%
# 2003-04-01 - Last Month Result: 3.90%
# 2003-05-01 - Last Month Result: 8.32%
# 2003-06-02 - Last Month Result: 5.09%
# 2003-07-01 - Last Month Result: -0.09%
# 2003-08-01 - Last Month Result: -1.95%
# 2003-09-02 - Last Month Result: 6.78%
# 2003-10-01 - Last Month Result: 0.06%
# 2003-11-03 - Last Month Result: 10.68%
# 2003-12-01 - Last Month Result: 3.43%
# 2004-01-02 - Last Month Result: -1.59%
# 2004-02-02 - Last Month Result: 3.24%
# 2004-03-01 - Last Month Result: 6.35%
# 2004-04-01 - Last Month Result: -2.60%
# 2004-05-03 - Last Month Result: -0.90%
# 2004-06-01 - Last Month Result: 1.77%
# 2004-07-01 - Last Month Result: 1.47%
# 2004-08-02 - Last Month Result: -2.22%
# 2004-09-01 - Last Month Result: -1.36%
# 2004-10-01 - Last Month Result: 2.25%
# 2004-11-01 - Last Month Result: 1.08%
# 2004-12-01 - Last Month Result: 8.69%
# 2005-01-03 - Last Month Result: 0.87%
# 2005-02-01 - Last Month Result: -0.13%
# 2005-03-01 - Last Month Result: 3.00%
# 2005-04-01 - Last Month Result: -1.18%
# 2005-05-02 - Last Month Result: -4.57%
# 2005-06-01 - Last Month Result: 4.96%
# 2005-07-01 - Last Month Result: 3.03%
# 2005-08-01 - Last Month Result: 2.58%
# 2005-09-01 - Last Month Result: 0.07%
# 2005-10-03 - Last Month Result: 2.70%
# 2005-11-01 - Last Month Result: -5.85%
# 2005-12-01 - Last Month Result: 6.38%
# 2006-01-03 - Last Month Result: 0.84%
# 2006-02-01 - Last Month Result: 4.41%
# 2006-03-01 - Last Month Result: 2.50%
# 2006-04-03 - Last Month Result: 3.88%
# 2006-05-01 - Last Month Result: -0.03%
# 2006-06-01 - Last Month Result: -3.68%
# 2006-07-03 - Last Month Result: 0.45%
# 2006-08-01 - Last Month Result: -2.73%
# 2006-09-01 - Last Month Result: 0.48%
# 2006-10-02 - Last Month Result: -0.04%
# 2006-11-01 - Last Month Result: 0.44%
# 2006-12-01 - Last Month Result: 2.21%
# 2007-01-03 - Last Month Result: 1.88%
# 2007-02-01 - Last Month Result: 3.76%
# 2007-03-01 - Last Month Result: -1.64%
# 2007-04-02 - Last Month Result: 3.53%
# 2007-05-01 - Last Month Result: 2.66%
# 2007-06-01 - Last Month Result: 3.70%
# 2007-07-02 - Last Month Result: -0.90%
# 2007-08-01 - Last Month Result: -4.24%
# 2007-09-04 - Last Month Result: 3.60%
# 2007-10-01 - Last Month Result: 3.35%
# 2007-11-01 - Last Month Result: -0.26%
# 2007-12-03 - Last Month Result: -1.59%
# 2008-01-02 - Last Month Result: 0.44%
# 2008-02-01 - Last Month Result: -8.70%
# 2008-03-03 - Last Month Result: 3.08%
# 2008-04-01 - Last Month Result: -0.61%
# 2008-05-01 - Last Month Result: 1.93%
# 2008-06-02 - Last Month Result: 1.37%
# 2008-07-01 - Last Month Result: -2.51%
# 2008-08-01 - Last Month Result: -7.61%
# 2008-09-02 - Last Month Result: -3.28%
# 2008-10-01 - Last Month Result: -8.05%
# 2008-11-03 - Last Month Result: -4.22%
# 2008-12-01 - Last Month Result: -0.98%
# 2009-01-02 - Last Month Result: 0.40%
# 2009-02-02 - Last Month Result: -0.06%
# 2009-03-02 - Last Month Result: 0.00%
# 2009-04-01 - Last Month Result: 0.33%
# 2009-05-01 - Last Month Result: -0.98%
# 2009-06-01 - Last Month Result: 0.49%
# 2009-07-01 - Last Month Result: -4.74%
# 2009-08-03 - Last Month Result: 12.08%
# 2009-09-01 - Last Month Result: 0.07%
# 2009-10-01 - Last Month Result: 5.78%
# 2009-11-02 - Last Month Result: -1.54%
# 2009-12-01 - Last Month Result: 7.67%
# 2010-01-04 - Last Month Result: 7.25%
# 2010-02-01 - Last Month Result: -6.45%
# 2010-03-01 - Last Month Result: 4.50%
# 2010-04-01 - Last Month Result: 5.26%
# 2010-05-03 - Last Month Result: 4.04%
# 2010-06-01 - Last Month Result: -11.89%
# 2010-07-01 - Last Month Result: -4.49%
# 2010-08-02 - Last Month Result: 5.74%
# 2010-09-01 - Last Month Result: 0.72%
# 2010-10-01 - Last Month Result: 2.21%
# 2010-11-01 - Last Month Result: 1.03%
# 2010-12-01 - Last Month Result: 4.08%
# 2011-01-03 - Last Month Result: 4.91%
# 2011-02-01 - Last Month Result: 0.52%
# 2011-03-01 - Last Month Result: 0.78%
# 2011-04-01 - Last Month Result: 5.85%
# 2011-05-02 - Last Month Result: -2.21%
# 2011-06-01 - Last Month Result: -4.54%
# 2011-07-01 - Last Month Result: 1.79%
# 2011-08-01 - Last Month Result: -4.02%
# 2011-09-01 - Last Month Result: -3.59%
# 2011-10-03 - Last Month Result: -4.81%
# 2011-11-01 - Last Month Result: 1.02%
# 2011-12-01 - Last Month Result: 0.24%
# 2012-01-03 - Last Month Result: -0.58%
# 2012-02-01 - Last Month Result: 0.94%
# 2012-03-01 - Last Month Result: 4.51%
# 2012-04-02 - Last Month Result: 5.34%
# 2012-05-01 - Last Month Result: 1.09%
# 2012-06-01 - Last Month Result: -10.40%
# 2012-07-02 - Last Month Result: 9.21%
# 2012-08-01 - Last Month Result: -0.58%
# 2012-09-04 - Last Month Result: 1.52%
# 2012-10-01 - Last Month Result: 0.64%
# 2012-11-01 - Last Month Result: -2.56%
# 2012-12-03 - Last Month Result: 1.10%
# 2013-01-02 - Last Month Result: 3.71%
# 2013-02-01 - Last Month Result: 5.46%
# 2013-03-01 - Last Month Result: 0.00%
# 2013-04-01 - Last Month Result: 5.53%
# 2013-05-01 - Last Month Result: -2.06%
# 2013-06-03 - Last Month Result: 9.56%
# 2013-07-01 - Last Month Result: -1.01%
# 2013-08-01 - Last Month Result: 8.62%
# 2013-09-03 - Last Month Result: -2.97%
# 2013-10-01 - Last Month Result: 3.78%
# 2013-11-01 - Last Month Result: 3.86%
# 2013-12-02 - Last Month Result: 3.35%
# 2014-01-02 - Last Month Result: 1.31%
# 2014-02-03 - Last Month Result: -2.94%
# 2014-03-03 - Last Month Result: 8.77%
# 2014-04-01 - Last Month Result: 0.48%
# 2014-05-01 - Last Month Result: -2.75%
# 2014-06-02 - Last Month Result: 1.43%
# 2014-07-01 - Last Month Result: 3.47%
# 2014-08-01 - Last Month Result: -4.25%
# 2014-09-02 - Last Month Result: 4.86%
# 2014-10-01 - Last Month Result: -4.25%
# 2014-11-03 - Last Month Result: 3.05%
# 2014-12-01 - Last Month Result: 0.83%
# 2015-01-02 - Last Month Result: 0.95%
# 2015-02-02 - Last Month Result: 1.47%
# 2015-03-02 - Last Month Result: 6.21%
# 2015-04-01 - Last Month Result: -0.14%
# 2015-05-01 - Last Month Result: -1.39%
# 2015-06-01 - Last Month Result: 2.89%
# 2015-07-01 - Last Month Result: -1.44%
# 2015-08-03 - Last Month Result: 2.28%
# 2015-09-01 - Last Month Result: -6.71%
# 2015-10-01 - Last Month Result: 1.20%
# 2015-11-02 - Last Month Result: 3.10%
# 2015-12-01 - Last Month Result: 1.06%
# 2016-01-04 - Last Month Result: -2.90%
# 2016-02-01 - Last Month Result: -0.81%
# 2016-03-01 - Last Month Result: 0.08%
# 2016-04-01 - Last Month Result: 2.10%
# 2016-05-02 - Last Month Result: -0.94%
# 2016-06-01 - Last Month Result: 0.72%
# 2016-07-01 - Last Month Result: 4.51%
# 2016-08-01 - Last Month Result: 0.57%
# 2016-09-01 - Last Month Result: -0.55%
# 2016-10-03 - Last Month Result: 1.24%
# 2016-11-01 - Last Month Result: -4.58%
# 2016-12-01 - Last Month Result: 7.04%
# 2017-01-03 - Last Month Result: 3.59%
# 2017-02-01 - Last Month Result: 0.25%
# 2017-03-01 - Last Month Result: 6.49%
# 2017-04-03 - Last Month Result: -4.94%
# 2017-05-01 - Last Month Result: 2.35%
# 2017-06-01 - Last Month Result: 4.23%
# 2017-07-03 - Last Month Result: -3.01%
# 2017-08-01 - Last Month Result: 4.52%
# 2017-09-01 - Last Month Result: 1.61%
# 2017-10-02 - Last Month Result: 2.07%
# 2017-11-01 - Last Month Result: 4.74%
# 2017-12-01 - Last Month Result: 3.13%
# 2018-01-02 - Last Month Result: 1.76%
# 2018-02-01 - Last Month Result: 7.32%
# 2018-03-01 - Last Month Result: -4.21%
# 2018-04-02 - Last Month Result: -2.81%
# 2018-05-01 - Last Month Result: 2.28%
# 2018-06-01 - Last Month Result: 4.66%
# 2018-07-02 - Last Month Result: 0.04%
# 2018-08-01 - Last Month Result: 0.55%
# 2018-09-04 - Last Month Result: 7.46%
# 2018-10-01 - Last Month Result: -1.40%
# 2018-11-01 - Last Month Result: -8.85%
# 2018-12-03 - Last Month Result: 1.74%
# 2019-01-02 - Last Month Result: -7.48%
# 2019-02-01 - Last Month Result: 0.42%
# 2019-03-01 - Last Month Result: 0.37%
# 2019-04-01 - Last Month Result: 0.41%
# 2019-05-01 - Last Month Result: -1.46%
# 2019-06-03 - Last Month Result: -5.61%
# 2019-07-01 - Last Month Result: 8.22%
# 2019-08-01 - Last Month Result: -0.54%
# 2019-09-03 - Last Month Result: 2.33%
# 2019-10-01 - Last Month Result: -3.24%
# 2019-11-01 - Last Month Result: 0.51%
# 2019-12-02 - Last Month Result: -0.18%
# 2020-01-02 - Last Month Result: 3.12%
# 2020-02-03 - Last Month Result: -2.89%
# 2020-03-02 - Last Month Result: -4.28%
# 2020-04-01 - Last Month Result: -21.61%
# 2020-05-01 - Last Month Result: 3.32%
# 2020-06-01 - Last Month Result: 1.23%
# 2020-07-01 - Last Month Result: 1.94%
# Annualized Return: 7.05% Max Drawdown: -42.71%

# %%
data = perf['portfolio_value'].copy()
data.index = data.index.date

data.to_csv('systematic_momentum.csv')

# %%
returns, positions, transactions = pf.utils.extract_rets_pos_txn_from_zipline(perf)
pf.create_returns_tear_sheet(returns, benchmark_rets=None)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;"><th>Start date</th><td colspan=2>2001-02-05</td></tr>
#     <tr style="text-align: right;"><th>End date</th><td colspan=2>2020-07-31</td></tr>
#     <tr style="text-align: right;"><th>Total months</th><td colspan=2>233</td></tr>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Backtest</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Annual return</th>
#       <td>7.1%</td>
#     </tr>
#     <tr>
#       <th>Cumulative returns</th>
#       <td>276.7%</td>
#     </tr>
#     <tr>
#       <th>Annual volatility</th>
#       <td>17.8%</td>
#     </tr>
#     <tr>
#       <th>Sharpe ratio</th>
#       <td>0.47</td>
#     </tr>
#     <tr>
#       <th>Calmar ratio</th>
#       <td>0.17</td>
#     </tr>
#     <tr>
#       <th>Stability</th>
#       <td>0.93</td>
#     </tr>
#     <tr>
#       <th>Max drawdown</th>
#       <td>-42.7%</td>
#     </tr>
#     <tr>
#       <th>Omega ratio</th>
#       <td>1.09</td>
#     </tr>
#     <tr>
#       <th>Sortino ratio</th>
#       <td>0.65</td>
#     </tr>
#     <tr>
#       <th>Skew</th>
#       <td>-0.52</td>
#     </tr>
#     <tr>
#       <th>Kurtosis</th>
#       <td>12.52</td>
#     </tr>
#     <tr>
#       <th>Tail ratio</th>
#       <td>0.94</td>
#     </tr>
#     <tr>
#       <th>Daily value at risk</th>
#       <td>-2.2%</td>
#     </tr>
#   </tbody>
# </table>
# /Users/leehongkai/anaconda/envs/trading/lib/python3.5/site-packages/numpy/core/fromnumeric.py:56: FutureWarning: 'argmin' is deprecated. Use 'idxmin' instead. The behavior of 'argmin' will be corrected to return the positional minimum in the future. Use 'series.values.argmin' to get the position of the minimum now.
#   return getattr(obj, method)(*args, **kwds)
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Worst drawdown periods</th>
#       <th>Net drawdown in %</th>
#       <th>Peak date</th>
#       <th>Valley date</th>
#       <th>Recovery date</th>
#       <th>Duration</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>42.71</td>
#       <td>2018-09-04</td>
#       <td>2020-03-23</td>
#       <td>NaT</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>36.06</td>
#       <td>2007-11-06</td>
#       <td>2009-07-07</td>
#       <td>2011-01-18</td>
#       <td>836</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>28.17</td>
#       <td>2002-03-19</td>
#       <td>2002-07-23</td>
#       <td>2003-10-09</td>
#       <td>408</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>19.65</td>
#       <td>2011-04-04</td>
#       <td>2011-08-08</td>
#       <td>2013-01-24</td>
#       <td>474</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>15.67</td>
#       <td>2001-08-24</td>
#       <td>2001-09-21</td>
#       <td>2002-02-26</td>
#       <td>133</td>
#     </tr>
#   </tbody>
# </table>

# %%
perf.portfolio_value.to_csv('125d version.csv')

# %%
df = pd.DataFrame(np.random.randn(10000, 1000))

# %%
# %time
df.lt(0).any().any()
# Out:
# CPU times: user 2 µs, sys: 1 µs, total: 3 µs
# Wall time: 5.01 µs
# True

# %%
# %time
(df < 0).any().any()
# Out:
# CPU times: user 3 µs, sys: 1e+03 ns, total: 4 µs
# Wall time: 6.91 µs
# True
