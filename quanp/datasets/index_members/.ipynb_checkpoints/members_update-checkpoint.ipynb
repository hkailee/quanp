# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('sp500.csv')
df['date'] = pd.to_datetime(df['date'], dayfirst=True )
df.set_index('date', inplace=True, drop=True)

df_mod = pd.read_csv('modification_20200802.csv')
df_mod['date'] = pd.to_datetime(df_mod['date'])
df_mod = df_mod.sort_values(by=['date'], ascending=True)
df_mod.set_index('date', inplace=True, drop=True)


df_dict = {}
for item in df.index:
    df_dict[item.strftime('%Y-%m-%d')] = df.at[item, 'tickers'].split(',')
    
last_date = df.index[-1:].strftime('%Y-%m-%d').values[0]
df_mod.index = df_mod.index.strftime('%Y-%m-%d')

for dt in df_mod.index.unique():
    df_dict[dt] = df_dict[last_date].copy()
    
    try:
        if df_mod.at[dt, 'ticker_add']:
            tick = df_mod.at[dt, 'ticker_add']
            df_dict[dt].append(tick)
            print('adding', df_mod.at[dt, 'ticker_add'])
            
    except:
        for tick in df_mod.at[dt, 'ticker_add']:
            if tick is not np.nan:
                df_dict[dt].append(tick)
                print('adding', tick)
                
    try:
        if df_mod.at[dt, 'ticker_drop']:
            df_dict[dt].remove(df_mod.at[dt, 'ticker_drop'])
            print('dropping', df_mod.at[dt, 'ticker_drop'])

    except:
        for tick in df_mod.at[dt, 'ticker_drop']:
            if tick is not np.nan:
                df_dict[dt].remove(tick)
                print('dropping', tick)
                
    last_date = dt
# Out:
# adding TFX
# dropping PCG
# adding ATO
# dropping NFX
# adding WAB
# dropping GT
# adding DOW
# dropping BHF
# adding CTVA
# dropping FLR
# adding BMS
# dropping MAT
# adding MKTX
# dropping LLL
# adding TMUS
# dropping RHT
# adding IEX
# adding LDOS
# dropping FL
# dropping APC
# adding CDW
# dropping TSS
# adding NVR
# dropping JEF
# adding LVS
# dropping NKTR
# adding NOW
# dropping CELG
# adding WRB
# dropping VIAB
# adding ODFL
# dropping STI
# adding ZBRA
# adding LYV
# adding STE
# dropping TRIP
# dropping AMG
# dropping MAC
# adding PAYC
# dropping WCG
# adding GDI
# dropping XEC
# adding CARR
# adding OTIS
# dropping RTN
# dropping M
# adding DXCM
# adding DPZ
# dropping AGN
# dropping CPRI
# adding WST
# dropping HP
# adding TYL
# adding TDY
# adding BIO
# dropping JWN
# dropping HOG
# dropping ADS

# %%
df_mod
# Out:
#            ticker_add ticker_drop
# 2019-01-18        TFX         PCG
# 2019-02-15        ATO         NFX
# 2019-02-27        WAB          GT
# 2019-04-02        DOW         BHF
# 2019-06-03       CTVA         FLR
# 2019-06-07        BMS         MAT
# 2019-07-01       MKTX         LLL
# 2019-07-15       TMUS         RHT
# 2019-08-09        IEX          FL
# 2019-08-09       LDOS         APC
# 2019-09-23        CDW         TSS
# 2019-09-26        NVR         JEF
# 2019-10-03        LVS        NKTR
# 2019-11-21        NOW        CELG
# 2019-12-05        WRB        VIAB
# 2019-12-09       ODFL         STI
# 2019-12-23       ZBRA        TRIP
# 2019-12-23        LYV         AMG
# 2019-12-23        STE         MAC
# 2020-01-28       PAYC         WCG
# 2020-03-03        GDI         XEC
# 2020-04-03       CARR         NaN
# 2020-04-03       OTIS         NaN
# 2020-04-06        NaN         RTN
# 2020-04-06        NaN           M
# 2020-05-12       DXCM         AGN
# 2020-05-12        DPZ        CPRI
# 2020-05-22        WST          HP
# 2020-06-22        TYL         JWN
# 2020-06-22        TDY         HOG
# 2020-06-22        BIO         ADS

# %%
df_final = pd.DataFrame(columns=['tickers'])

for key in df_dict.keys():
#     df_final.at[key, 'tickers'] = df_dict[key]
    df_final.at[key, 'tickers'] = ','.join(df_dict[key])

# %%
# for date in df_final.index[-24:]:
#     print(date)
#     print(df_final.at[date, 'tickers'])

# %%
pd.to_datetime(df_final.index)
# Out:
# DatetimeIndex(['1996-01-02', '1996-01-03', '1996-01-04', '1996-01-10',
#                '1996-01-11', '1996-01-12', '1996-01-22', '1996-01-23',
#                '1996-01-24', '1996-01-30',
#                ...
#                '2019-12-05', '2019-12-09', '2019-12-23', '2020-01-28',
#                '2020-03-03', '2020-04-03', '2020-04-06', '2020-05-12',
#                '2020-05-22', '2020-06-22'],
#               dtype='datetime64[ns]', length=2618, freq=None)

# %%
df_final.to_csv('sp500_20100801.csv')

# %% [markdown]
# # drop any company that has value nan

# %%
import os
csv_dir ='../../Data/daily/'
# filter out downloaded tickers
downloaded_tickers = os.listdir(csv_dir)
print(len(downloaded_tickers))

ls_csv_with_na = []
count_df_na = 0
for csv in downloaded_tickers:
    df = pd.read_csv(csv_dir + csv, index_col=0)
    if df.isnull().values.any():
        count_df_na += 1
        ls_csv_with_na.append(csv)
#     print(df.index[-1])
        
        
#     break
# Out:
# 575

# %%
count_df_na
# Out:
# 0

# %%
for csv in ls_csv_with_na:
    os.remove(csv_dir + csv)

# %%
df_check = pd.read_csv(csv_dir + 'VRTX.csv', index_col=0)
df_check.isnull()
# Out:
#              open   high    low  close  volume
# 2000-07-31  False  False  False  False   False
# 2000-08-01  False  False  False  False   False
# 2000-08-02  False  False  False  False   False
# 2000-08-03  False  False  False  False   False
# 2000-08-04  False  False  False  False   False
# 2000-08-07  False  False  False  False   False
# 2000-08-08  False  False  False  False   False
# 2000-08-09  False  False  False  False   False
# 2000-08-10  False  False  False  False   False
# 2000-08-11  False  False  False  False   False
# 2000-08-14  False  False  False  False   False
# 2000-08-15  False  False  False  False   False
# 2000-08-16  False  False  False  False   False
# 2000-08-17  False  False  False  False   False
# 2000-08-18  False  False  False  False   False
# 2000-08-21  False  False  False  False   False
# 2000-08-22  False  False  False  False   False
# 2000-08-23  False  False  False  False   False
# 2000-08-24  False  False  False  False   False
# 2000-08-25  False  False  False  False   False
# 2000-08-28  False  False  False  False   False
# 2000-08-29  False  False  False  False   False
# 2000-08-30  False  False  False  False   False
# 2000-08-31  False  False  False  False   False
# 2000-09-01  False  False  False  False   False
# 2000-09-05  False  False  False  False   False
# 2000-09-06  False  False  False  False   False
# 2000-09-07  False  False  False  False   False
# 2000-09-08  False  False  False  False   False
# 2000-09-11  False  False  False  False   False
# ...           ...    ...    ...    ...     ...
# 2020-06-19  False  False  False  False   False
# 2020-06-22  False  False  False  False   False
# 2020-06-23  False  False  False  False   False
# 2020-06-24  False  False  False  False   False
# 2020-06-25  False  False  False  False   False
# 2020-06-26  False  False  False  False   False
# 2020-06-29  False  False  False  False   False
# 2020-06-30  False  False  False  False   False
# 2020-07-01  False  False  False  False   False
# 2020-07-02  False  False  False  False   False
# 2020-07-06  False  False  False  False   False
# 2020-07-07  False  False  False  False   False
# 2020-07-08  False  False  False  False   False
# 2020-07-09  False  False  False  False   False
# 2020-07-10  False  False  False  False   False
# 2020-07-13  False  False  False  False   False
# 2020-07-14  False  False  False  False   False
# 2020-07-15  False  False  False  False   False
# 2020-07-16  False  False  False  False   False
# 2020-07-17  False  False  False  False   False
# 2020-07-20  False  False  False  False   False
# 2020-07-21  False  False  False  False   False
# 2020-07-22  False  False  False  False   False
# 2020-07-23  False  False  False  False   False
# 2020-07-24  False  False  False  False   False
# 2020-07-27  False  False  False  False   False
# 2020-07-28  False  False  False  False   False
# 2020-07-29  False  False  False  False   False
# 2020-07-30  False  False  False  False   False
# 2020-07-31  False  False  False  False   False
#
# [5033 rows x 5 columns]
